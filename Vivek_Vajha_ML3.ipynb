# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
df=pd.read_csv("test_data_cleaning.csv")

# %%
df
# Out:
#          id keyword location  \
# 0         0     NaN      NaN
# 1         2     NaN      NaN
# 2         3     NaN      NaN
# 3         9     NaN      NaN
# 4        11     NaN      NaN
# ...     ...     ...      ...
# 3258  10861     NaN      NaN
# 3259  10865     NaN      NaN
# 3260  10868     NaN      NaN
# 3261  10874     NaN      NaN
# 3262  10875     NaN      NaN
#
#                                                    text
# 0                    Just happened a terrible car crash
# 1     Heard about  # earthquake is different cities,...
# 2     there is a forest fire at spot pond, geese are...
# 3        Apocalypse lighting .   # Spokane  # wildfires
# 4         Typhoon Soudelor kills 28 in China and Taiwan
# ...                                                 ...
# 3258  EARTHQUAKE SAFETY LOS ANGELES  SAFETY FASTENER...
# 3259  Storm in RI worse than last hurricane .  My ci...
# 3260                  Green Line derailment in Chicago
# ...

# %%
df.isnull().sum()
# Out:
# id             0
# keyword       26
# location    1105
# text           0
# dtype: int64

# %%
df11=pd.DataFrame(data={"Temperature":[1,np.nan,3,2,5],"Humidity":[22,np.nan,2,np.nan,22]})
df11
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 1          NaN       NaN
# 2          3.0       2.0
# 3          2.0       NaN
# 4          5.0      22.0

# %%
df11.isnull().sum()
# Out:
# Temperature    1
# Humidity       2
# dtype: int64

# %%
df11.dropna()
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 2          3.0       2.0
# 4          5.0      22.0

# %%
df11.fillna(method='bfill')
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 1          3.0       2.0
# 2          3.0       2.0
# 3          2.0      22.0
# 4          5.0      22.0

# %%
df11.isnull().sum()
# Out:
# Temperature    1
# Humidity       2
# dtype: int64

# %%
df11
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 1          NaN       NaN
# 2          3.0       2.0
# 3          2.0       NaN
# 4          5.0      22.0

# %%
df11.interpolate()
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 1          2.0      12.0
# 2          3.0       2.0
# 3          2.0      12.0
# 4          5.0      22.0

# %%
df11.fillna({'Temperature':2, 'Humidity':15})
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 1          2.0      15.0
# 2          3.0       2.0
# 3          2.0      15.0
# 4          5.0      22.0

# %%
df11.fillna({'Humidity':15})
# Out:
#    Temperature  Humidity
# 0          1.0      22.0
# 1          NaN      15.0
# 2          3.0       2.0
# 3          2.0      15.0
# 4          5.0      22.0
